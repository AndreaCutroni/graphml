# %% [markdown]
# ## EVACUATION GRAPH

# %% [markdown]
# ## 1. Import the needed libraries

# %%
from topologicpy.Vertex import Vertex
from topologicpy.Face import Face
from topologicpy.Shell import Shell
from topologicpy.Cell import Cell
from topologicpy.CellComplex import CellComplex
from topologicpy.Cluster import Cluster
from topologicpy.Topology import Topology
from topologicpy.Dictionary import Dictionary
from topologicpy.Graph import Graph
from topologicpy.Helper import Helper
from topologicpy.Grid import Grid
from topologicpy.Color import Color

# %% [markdown]
# ## 2. Check the TopologicPy version

# %%
print(Helper.Version())
# Out:
# The version that you are using (0.9.18) is OLDER than the latest version (0.9.20) from PyPI. Please consider upgrading to the latest version.

# %% [markdown]
# ## 3. Set renderer

# %%
renderer = "vscode"

# %% [markdown]
# ## 4. Import OBJ file

# %%
geometry = Topology.ByOBJPath(r"C:\Users\cutro\Documents\GitHub\macad\graphml\Assets\Layout_Rooms.obj", selfMerge=True)
cells = Topology.Cells(geometry[0])
cc = CellComplex.ByCells(cells)
Topology.Analyze(cc)
# Out:
# 'OVERALL ANALYSIS\n================\nThe shape is a cellComplex.\nNumber of cells = 18\nNumber of shells = 18\nNumber of faces = 610\nNumber of wires = 610\nNumber of edges = 976\nNumber of vertices = 385\n\n\nINDIVIDUAL ANALYSIS\n================\nThe shape is a cellComplex.\nNumber of cells = 18\n================\n  The shape is a cell.\n  Number of shells = 1\n  ================\n    The shape is a shell.\n    Number of faces = 37\n    ================\n      The shape is a face.\n      Number of wires = 1\n      ================\n        The shape is a wire.\n        Number of edges = 6\n        ================\n          The shape is an edge.\n          Number of vertices = 2\n          ================\n            The shape is a vertex.\n            ================\n            The shape is a vertex.\n            ================\n          The shape is an edge.\n          Number of vertices = 2\n          ================\n            The shape is a vertex.\n            ================\n            The shape is a vertex.\n            ================\n          The shape is an edge.\n          Number of vertices = 2\n          ================\n            The shape is a vertex.\n            ================\n            The shape is a vertex.\n            ================\n          The shape is an edge.\n          Number of vertices = 2\n          ================\n            The shape is a vertex.\n            ================\n            The shape is a vertex.\n            ================\n          The shape is an edge.\n          Number of vertices = 2\n          ================\n            The shape is a vertex.\n            ================\n            The shape is a vertex.\n            ================\n          The shape is an edge.\n          Number of vertices = 2\n          ================\n            The shape is a vertex.\n            ================\n            The shape is a vertex.\n            ================\n      The shape is a face.\n      Number of wires = 1\n      ================\n        The shape is a wire.\n        Number of edges = 4\n        ================\n          The shape is an edge.\n          Number of vertices = 2\n          ================\n            The shape is a vertex.\n            ================\n            The shape is a vertex.\n            ================\n          The shape is an edge.\n          Number of vertices = 2\n          ================\n            The shape is a vertex.\n            ================\n            The shape is a vertex.\n            ================\n          The shape is an edge.\n          Number of vertices = 2\n          ================\n            The shape is a vertex.\n            ================\n            The shape is a vertex.\n            ================\n          The shape is an edge.\n          Number of vertices = 2\n          ================\n            The shape is a vertex.\n            ================\n            The shape is a vertex.\n            ================\n      The shape is a face.\n      Number of wires = 1\n      ================\n        The shape is a wire.\n        Number of edges = 5\n        ================\n          The shape is an edge.\n          Number of vertices = 2\n          ================\n            The shape is a vertex.\n            ================\n            The shape is a vertex.\n            ================\n          The shape is an edge.\n          Number of vertices = 2\n          ================\n            The shape is a vertex.\n            ================\n            The shape is a vertex.\n            ================\n          The shape is an edge.\n          Number of vertices = 2\n          ================\n            The shape is a vertex.\n            ================\n            The shape is a vertex.\n            ================\n          The shape is an edge.\n          Number of vertices = 2\n          ================\n  ...

# %% [markdown]
# ## 5. Show the geometry

# %%
Topology.Show(cc,
              backgroundColor="white",
              width=500,
              height=500,
              renderer=renderer)

# %% [markdown]
# ## Derive Dual Graph

# %%
g1 = Graph.ByTopology(cc, direct=True) #direct means that we are ignoring the doors

# %% [markdown]
# ## Visualization

# %%
vertices = Graph.Vertices(g1)
for v in vertices:
    d = Dictionary.ByKeysValues(["size", "color"], [18, "red"])
    v = Topology.SetDictionary(v, d)
edges = Graph.Edges(g1)
for e in edges:
    d = Topology.Dictionary(e)
    d = Dictionary.SetValuesAtKeys(d, ["width", "color"], [4, "black"]) #to expand the dictionary and not overwrite it and then put it back
    e = Topology.SetDictionary(e, d)

# %% [markdown]
# ## Show Geometry and Graph

# %%
Topology.Show(cc, g1,
              vertexSizeKey="size",
              vertexColorKey="color",
              edgeWidthKey="width",
              edgeColorKey="color",
              faceOpacity=0.3,
              backgroundColor="white",
              width=500,
              height=500,
              renderer=renderer)

# %% [markdown]
# ## Add Apertures from OBJ

# %%
apertures = Topology.ByOBJPath(r"C:\Users\cutro\Documents\GitHub\macad\graphml\Assets\Layout_Apertures.obj", selfMerge=True)

# %%
Topology.Show(apertures,
              backgroundColor="white",
              width=500,
              height=500,
              renderer=renderer)

# %%
geometryWithApertures = Topology.AddApertures(cc, apertures, subTopologyType="face")

# %%
g2 = Graph.ByTopology(geometryWithApertures, direct=True, viaSharedApertures=True)

# %%
vertices = Graph.Vertices(g2)
for v in vertices:
    d = Dictionary.ByKeysValues(["size", "color"], [18, "red"])
    v = Topology.SetDictionary(v, d)
edges = Graph.Edges(g2)
for e in edges:
    d = Topology.Dictionary(e)
    d = Dictionary.SetValuesAtKeys(d, ["width", "color"], [4, "black"]) #to expand the dictionary and not overwrite it and then put it back
    e = Topology.SetDictionary(e, d)

# %%
Topology.Show(cc, apertures, g2,
              vertexSizeKey="size",
              vertexColorKey="color",
              edgeWidthKey="width",
              edgeColorKey="color",
              faceOpacity=0.3,
              backgroundColor="white",
              width=500,
              height=500,
              renderer=renderer)
